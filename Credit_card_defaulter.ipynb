# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import accuracy_score

# %%
input_df = pd.read_csv(r"C:\Adithya\Python\Machine_Learning\Credit_Card_Fraud_Detection\Input_File\creditcard.csv")

# %%
#initial 5 rows
input_df.head()
# Out:
#    Time        V1        V2        V3        V4        V5        V6        V7  \
# 0   0.0 -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 1   0.0  1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 2   1.0 -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 3   1.0 -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 4   2.0 -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#          V8        V9  ...       V21       V22       V23       V24       V25  \
# 0  0.098698  0.363787  ... -0.018307  0.277838 -0.110474  0.066928  0.128539
# 1  0.085102 -0.255425  ... -0.225775 -0.638672  0.101288 -0.339846  0.167170
# 2  0.247676 -1.514654  ...  0.247998  0.771679  0.909412 -0.689281 -0.327642
# 3  0.377436 -1.387024  ... -0.108300  0.005274 -0.190321 -1.175575  0.647376
# 4 -0.270533  0.817739  ... -0.009431  0.798278 -0.137458  0.141267 -0.206010
#
# ...

# %%
#Checking all the transactions with fraudlent transactions
input_df[input_df['Class']==1]
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 541        406.0 -2.312227  1.951992 -1.609851  3.997906 -0.522188 -1.426545
# 623        472.0 -3.043541 -3.157307  1.088463  2.288644  1.359805 -1.064823
# 4920      4462.0 -2.303350  1.759247 -0.359745  2.330243 -0.821628 -0.075788
# 6108      6986.0 -4.397974  1.358367 -2.592844  2.679787 -1.128131 -1.706536
# 6329      7519.0  1.234235  3.019740 -4.304597  4.732795  3.624201 -1.357746
# ...          ...       ...       ...       ...       ...       ...       ...
# 279863  169142.0 -1.927883  1.125653 -4.518331  1.749293 -1.566487 -2.010494
# 280143  169347.0  1.378559  1.289381 -5.004247  1.411850  0.442581 -1.326536
# 280149  169351.0 -0.676143  1.126366 -2.213700  0.468308 -1.120541 -0.003346
# 281144  169966.0 -3.113832  0.585864 -5.399730  1.817092 -0.840618 -2.943548
# 281674  170348.0  1.991976  0.158476 -2.583441  0.408670  1.151147 -0.096695
#
# ...

# %%
#General info about data
input_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 284807 entries, 0 to 284806
# Data columns (total 31 columns):
#  #   Column  Non-Null Count   Dtype
# ---  ------  --------------   -----
#  0   Time    284807 non-null  float64
#  1   V1      284807 non-null  float64
#  2   V2      284807 non-null  float64
#  3   V3      284807 non-null  float64
#  4   V4      284807 non-null  float64
#  5   V5      284807 non-null  float64
#  6   V6      284807 non-null  float64
#  7   V7      284807 non-null  float64
#  8   V8      284807 non-null  float64
#  9   V9      284807 non-null  float64
#  10  V10     284807 non-null  float64
#  11  V11     284807 non-null  float64
#  12  V12     284807 non-null  float64
#  13  V13     284807 non-null  float64
#  14  V14     284807 non-null  float64
#  15  V15     284807 non-null  float64
#  16  V16     284807 non-null  float64
#  17  V17     284807 non-null  float64
#  18  V18     284807 non-null  float64
#  19  V19     284807 non-null  float64
# ...

# %%
#Checking for null values
input_df.isnull().sum()
# Out:
# Time      0
# V1        0
# V2        0
# V3        0
# V4        0
# V5        0
# V6        0
# V7        0
# V8        0
# V9        0
# V10       0
# V11       0
# V12       0
# V13       0
# V14       0
# V15       0
# V16       0
# V17       0
# V18       0
# V19       0
# V20       0
# V21       0
# V22       0
# V23       0
# V24       0
# V25       0
# V26       0
# V27       0
# V28       0
# Amount    0
# Class     0
# dtype: int64

# %%
#distribution of legit transactions and fraudlent transactions
input_df['Class'].value_counts()
# Out:
# Class
# 0    284315
# 1       492
# Name: count, dtype: int64

# %% [markdown]
# This dataset is highly unbalanced
# 0 -> Normal Transaction
# 1 -> Fraudlent Transaction

# %%
#Separating the data for analysis
legit_df = input_df[input_df['Class']==0]
fraud_df = input_df[input_df['Class']==1]

# %%
print(legit_df.shape)
print(fraud_df.shape)
# Out:
# (284315, 31)
# (492, 31)

# %%
#Amount column statistics - legit
legit_df['Amount'].describe()
# Out:
# count    284315.000000
# mean         88.291022
# std         250.105092
# min           0.000000
# 25%           5.650000
# 50%          22.000000
# 75%          77.050000
# max       25691.160000
# Name: Amount, dtype: float64

# %%
#Amount column statistics - fraud
fraud_df['Amount'].describe()
# Out:
# count     492.000000
# mean      122.211321
# std       256.683288
# min         0.000000
# 25%         1.000000
# 50%         9.250000
# 75%       105.890000
# max      2125.870000
# Name: Amount, dtype: float64

# %%
legit_df = legit_df.dropna(subset=['Amount'])

# %%
legit_df.shape
# Out:
# (284315, 31)

# %%
input_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %% [markdown]
# Build a sample dataset containing similar distribution of legit transactions and Fraudlent transactions - This is done in order to overcome the unbalanced dataset

# %%
legit_sample = legit_df.sample(n=492)

# %%
legit_sample.describe()
# Out:
#                 Time          V1          V2          V3          V4  \
# count     492.000000  492.000000  492.000000  492.000000  492.000000
# mean    97862.113821   -0.146842    0.016216   -0.128624    0.038225
# std     46092.761060    2.165809    1.629535    1.529787    1.394533
# min       631.000000  -13.485138  -15.161015  -13.621197   -3.755860
# 25%     59503.750000   -1.090173   -0.557305   -0.907937   -0.788725
# 50%     87738.000000   -0.040486    0.105185    0.000479    0.025350
# 75%    141160.500000    1.288063    0.824452    0.861975    0.861809
# max    172405.000000    2.299989    8.977926    3.478213    4.974028
#
#                V5          V6          V7          V8          V9  ...  \
# count  492.000000  492.000000  492.000000  492.000000  492.000000  ...
# mean    -0.021131    0.008589    0.081500    0.076028   -0.036177  ...
# std      1.410482    1.370426    1.246437    0.916173    1.073711  ...
# ...

# %%
legit_sample.shape
# Out:
# (492, 31)

# %%
new_sample_dataset = pd.concat([legit_sample,fraud_df],axis=0)
new_sample_dataset.shape
# Out:
# (984, 31)

# %%
new_sample_dataset.head()
# Out:
#             Time        V1        V2        V3        V4        V5        V6  \
# 110831   71993.0 -0.923531  0.281053  1.681561  0.997668  0.844026 -0.635176
# 195671  131170.0 -0.236816  0.943198 -0.968759 -0.565803  0.518020 -0.684578
# 114702   73589.0 -1.090018  0.192800  0.083116 -0.196742  3.412001  3.135061
# 249593  154485.0 -1.692392 -0.179935 -0.438898 -1.208696  2.334419  3.869538
# 219601  141796.0 -9.987291 -8.251145 -3.978605 -0.089997 -3.996769  3.601971
#
#               V7        V8        V9  ...       V21       V22       V23  \
# 110831 -0.111969  0.150008 -1.030064  ... -0.131488 -0.649235 -0.037343
# 195671  1.013397  0.133683 -0.309015  ...  0.071782  0.117493 -0.068849
# 114702 -0.295385  0.539861 -0.291834  ... -0.121869 -0.136801 -0.551050
# 249593 -0.862481  1.403796  0.212057  ...  0.213817  0.872997  0.206379
# 219601  3.925340  0.297266 -0.702305  ... -1.156314 -0.808616 -0.841085
#
# ...

# %%
new_sample_dataset['Class'].value_counts()
# Out:
# Class
# 0    492
# 1    492
# Name: count, dtype: int64

# %%
#checking the mean of new sample
new_sample_dataset.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      97862.113821 -0.146842  0.016216 -0.128624  0.038225 -0.021131
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.008589  0.081500  0.076028 -0.036177  ... -0.020174 -0.021910
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0      0.037758  0.053970 -0.059892 -0.037389  0.004298 -0.042890 -0.024374
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       91.437500
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#checking the mean of old sample
input_df.groupby('Class').mean()
# Out:
#                Time        V1        V2        V3        V4        V5  \
# Class
# 0      94838.202258  0.008258 -0.006271  0.012171 -0.007860  0.005453
# 1      80746.806911 -4.771948  3.623778 -7.033281  4.542029 -3.151225
#
#              V6        V7        V8        V9  ...       V20       V21  \
# Class                                          ...
# 0      0.002419  0.009637 -0.000987  0.004467  ... -0.000644 -0.001235
# 1     -1.397737 -5.568731  0.570636 -2.581123  ...  0.372319  0.713588
#
#             V22       V23       V24       V25       V26       V27       V28  \
# Class
# 0     -0.000024  0.000070  0.000182 -0.000072 -0.000089 -0.000295 -0.000131
# 1      0.014049 -0.040308 -0.105130  0.041449  0.051648  0.170575  0.075667
#
#            Amount
# Class
# 0       88.291022
# 1      122.211321
#
# [2 rows x 30 columns]

# %%
#Separating the dependent and independent vairables
X=new_sample_dataset.drop(columns='Class',axis=1)
Y=new_sample_dataset['Class']

# %%
#Checking the shape of newly created variables
print(X.shape)
print(Y.shape)
# Out:
# (984, 30)
# (984,)

# %%
#Splitting the dataset in to test and train dataset
X_train, X_test, Y_train, Y_test = train_test_split(X,Y,test_size=0.2,stratify=Y,random_state=2)

# %%
#shape of all the test and train data
print(X_train.shape)
print(X_test.shape)
print(Y_train.shape)
print(Y_test.shape)
# Out:
# (787, 30)
# (197, 30)
# (787,)
# (197,)

# %%
#Defining the logistic regression model
model = LogisticRegression()

# %%
# Training the logistic regression model with training data
model.fit(X_train,Y_train)
# Out:
# C:\Users\adith\anaconda3\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
#Model Evaluation
#Based on accuracy score
#Accuracy on training data
X_train_prediction = model.predict(X_train)
training_data_accuracy = accuracy_score(X_train_prediction,Y_train)

# %%
print('Accuracy on training data :', training_data_accuracy)
# Out:
# Accuracy on training data : 0.9390088945362135

# %%
#Model Evaluation
#Based on accuracy score
#Accuracy on training data
X_test_prediction = model.predict(X_test)
testing_data_accuracy = accuracy_score(X_test_prediction,Y_test)

# %%
print('Accuracy on testing data :', testing_data_accuracy)
# Out:
# Accuracy on testing data : 0.9289340101522843
